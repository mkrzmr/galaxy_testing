# %%
import requests
import time
import os
import re
import shutil

publication = (GALAXY_INPUTS['publication']).lower()
year = (GALAXY_INPUTS['year'])

def sanitize_filename(name):
    """Removes characters that are illegal in filenames."""
    return re.sub(r'[<>:"/\\ |?*]', '_', name)

def zip_and_put_to_galaxy(year, source_folder):
    """
    Zips the folder, sends it to Galaxy history, and cleans up raw files.
    """
    print("\n--- Starting Export to Galaxy ---")
    
    # 1. Zip the folder
    zip_base_name = f"downloads_{year}" # shutil adds .zip automatically
    print(f"Zipping folder: {source_folder}...")
    
    try:
        # shutil.make_archive(base_name, format, root_dir)
        zip_path = shutil.make_archive(zip_base_name, 'zip', source_folder)
        print(f"Archive created: {zip_path}")
        
        # 2. Send to Galaxy
        print("Sending zip file to Galaxy History...")
        put(f"{zip_base_name}.zip")
        print("Successfully sent to History.")

        # 3. Clean up (Delete raw files to save space)
        print("Cleaning up raw files...")
        shutil.rmtree(source_folder)
        print("Raw files deleted successfully.")

    except Exception as e:
        print(f"Error during export/cleanup: {e}")

def extract_date_from_label(label):
    """
    Tries to find a date in YYYY-MM-DD format within the label string.
    Returns the date string or 'unknown_date' if not found.
    """
    # Look for pattern YYYY-MM-DD
    match = re.search(r'(\d{4}-\d{2}-\d{2})', label)
    if match:
        return match.group(1)
    return "unknown_date"

def download_newspaper_year(year):
    base_folder = f"outputs/collection/downloads_{year}"
    
    # 1. Construct the Collection URL
    collection_url = f"https://iiif.onb.ac.at/presentation/collection/{publication}_{year}"
    print(f"Fetching Collection: {collection_url}")

    try:
        response = requests.get(collection_url)
        response.raise_for_status()
        collection_data = response.json()
    except Exception as e:
        print(f"Error fetching collection: {e}")
        return

    if "manifests" not in collection_data:
        print("No manifests found.")
        return

    print(f"Found {len(collection_data['manifests'])} issues. Starting download...\n")

    # 2. Iterate through Manifests (Issues)
    for i, manifest_entry in enumerate(collection_data["manifests"]):
        manifest_url = manifest_entry.get("@id")
        manifest_label = manifest_entry.get("label", f"Issue_{i}")
        
        # --- NEW: Extract Date for Filename ---
        issue_date = extract_date_from_label(manifest_label)
        
        # Create a clean folder name for this sequence/issue
        safe_folder_name = sanitize_filename(manifest_label)
        issue_path = os.path.join(base_folder, safe_folder_name)
        
        # Create the directory if it doesn't exist
        os.makedirs(issue_path, exist_ok=True)
        
        print(f"[{i+1}] Processing: {manifest_label} (Date: {issue_date})")

        try:
            m_response = requests.get(manifest_url)
            m_data = m_response.json()
            
            # 3. Iterate through Sequences -> Canvases (Pages)
            sequences = m_data.get("sequences", [])
            for sequence in sequences:
                canvases = sequence.get("canvases", [])
                
                print(f"    - Found {len(canvases)} pages.")
                
                for canvas in canvases:
                    # Get the page label (usually "0001", "0002", etc.)
                    # We strip to remove whitespace and zfill to ensure correct sorting (e.g., 001)
                    raw_page_label = str(canvas.get("label", "0")).strip()
                    clean_page_label = raw_page_label.zfill(4) 
                    
                    # --- NEW: Construct Filename with Date ---
                    # Format: 1756-01-03_page_0001.jpg
                    filename = f"{issue_date}_page_{clean_page_label}.jpg"
                    
                    # --- FIX: Join folder + filename ---
                    file_path = os.path.join(issue_path, filename)

                    # Skip if already downloaded
                    if os.path.exists(file_path):
                        # print(f"      [Skipping] {filename} exists.") # Optional: Reduce clutter
                        continue

                    # Find the image URL
                    images = canvas.get("images", [])
                    for image in images:
                        resource = image.get("resource", {})
                        image_url = resource.get("@id")
                        
                        if image_url:
                            print(f"      Downloading {filename}...", end="\r")
                            try:
                                img_r = requests.get(image_url, stream=True)
                                img_r.raise_for_status()
                                with open(file_path, 'wb') as f:
                                    for chunk in img_r.iter_content(chunk_size=8192):
                                        f.write(chunk)
                            except Exception as e:
                                print(f"\n      Error downloading {image_url}: {e}")
                            
                            time.sleep(0.2)
                print("") 

        except Exception as e:
            print(f"    Error processing manifest {manifest_url}: {e}")

        # Sleep between issues
        time.sleep(0.5)

    print("\nAll downloads complete!")
    zip_and_put_to_galaxy(year, base_folder)
    print("\nExport complete")

if __name__ == "__main__":
    download_newspaper_year(year)
# Out:
# Enter year (e.g., 1756):  1756
# Fetching Collection: https://iiif.onb.ac.at/presentation/collection/wrz_1756
# Found 104 issues. Starting download...
#
# [1] Processing: Wiener Zeitung 1756-01-03
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [2] Processing: Wiener Zeitung 1756-01-07
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [3] Processing: Wiener Zeitung 1756-01-10
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [4] Processing: Wiener Zeitung 1756-01-14
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [5] Processing: Wiener Zeitung 1756-01-17
#     - Found 12 pages.
#       Downloading 00000012.jpg...
# [6] Processing: Wiener Zeitung 1756-01-21
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [7] Processing: Wiener Zeitung 1756-01-24
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [8] Processing: Wiener Zeitung 1756-01-28
#     - Found 14 pages.
#       Downloading 00000014.jpg...
# [9] Processing: Wiener Zeitung 1756-01-31
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [10] Processing: Wiener Zeitung 1756-02-04
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [11] Processing: Wiener Zeitung 1756-02-07
#     - Found 12 pages.
#       Downloading 00000012.jpg...
# [12] Processing: Wiener Zeitung 1756-02-11
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [13] Processing: Wiener Zeitung 1756-02-14
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [14] Processing: Wiener Zeitung 1756-02-18
#     - Found 12 pages.
#       Downloading 00000012.jpg...
# [15] Processing: Wiener Zeitung 1756-02-21
#     - Found 12 pages.
#       Downloading 00000012.jpg...
# [16] Processing: Wiener Zeitung 1756-02-25
#     - Found 12 pages.
#       Downloading 00000012.jpg...
# [17] Processing: Wiener Zeitung 1756-02-28
#     - Found 12 pages.
#       Downloading 00000012.jpg...
# [18] Processing: Wiener Zeitung 1756-03-03
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [19] Processing: Wiener Zeitung 1756-03-06
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [20] Processing: Wiener Zeitung 1756-03-10
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [21] Processing: Wiener Zeitung 1756-03-13
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [22] Processing: Wiener Zeitung 1756-03-17
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [23] Processing: Wiener Zeitung 1756-03-20
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [24] Processing: Wiener Zeitung 1756-03-24
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [25] Processing: Wiener Zeitung 1756-03-27
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [26] Processing: Wiener Zeitung 1756-03-31
#     - Found 12 pages.
#       Downloading 00000012.jpg...
# [27] Processing: Wiener Zeitung 1756-04-03
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [28] Processing: Wiener Zeitung 1756-04-07
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [29] Processing: Wiener Zeitung 1756-04-10
#     - Found 14 pages.
#       Downloading 00000014.jpg...
# [30] Processing: Wiener Zeitung 1756-04-14
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [31] Processing: Wiener Zeitung 1756-04-17
#     - Found 8 pages.
#       Downloading 00000008.jpg...
# [32] Processing: Wiener Zeitung 1756-04-21
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [33] Processing: Wiener Zeitung 1756-04-24
#     - Found 12 pages.
#       Downloading 00000012.jpg...
# [34] Processing: Wiener Zeitung 1756-04-28
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [35] Processing: Wiener Zeitung 1756-05-01
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [36] Processing: Wiener Zeitung 1756-05-05
#     - Found 12 pages.
#       Downloading 00000012.jpg...
# [37] Processing: Wiener Zeitung 1756-05-08
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [38] Processing: Wiener Zeitung 1756-05-12
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [39] Processing: Wiener Zeitung 1756-05-15
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [40] Processing: Wiener Zeitung 1756-05-19
#     - Found 14 pages.
#       Downloading 00000014.jpg...
# [41] Processing: Wiener Zeitung 1756-05-22
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [42] Processing: Wiener Zeitung 1756-05-26
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [43] Processing: Wiener Zeitung 1756-05-27
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [44] Processing: Wiener Zeitung 1756-06-02
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [45] Processing: Wiener Zeitung 1756-06-05
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [46] Processing: Wiener Zeitung 1756-06-09
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [47] Processing: Wiener Zeitung 1756-06-12
#     - Found 12 pages.
#       Downloading 00000012.jpg...
# [48] Processing: Wiener Zeitung 1756-06-16
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [49] Processing: Wiener Zeitung 1756-06-19
#     - Found 12 pages.
#       Downloading 00000012.jpg...
# [50] Processing: Wiener Zeitung 1756-06-23
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [51] Processing: Wiener Zeitung 1756-06-26
#     - Found 18 pages.
#       Downloading 00000018.jpg...
# [52] Processing: Wiener Zeitung 1756-06-30
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [53] Processing: Wiener Zeitung 1756-07-03
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [54] Processing: Wiener Zeitung 1756-07-07
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [55] Processing: Wiener Zeitung 1756-07-10
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [56] Processing: Wiener Zeitung 1756-07-14
#     - Found 12 pages.
#       Downloading 00000012.jpg...
# [57] Processing: Wiener Zeitung 1756-07-17
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [58] Processing: Wiener Zeitung 1756-07-21
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [59] Processing: Wiener Zeitung 1756-07-24
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [60] Processing: Wiener Zeitung 1756-07-28
#     - Found 16 pages.
#       Downloading 00000016.jpg...
# [61] Processing: Wiener Zeitung 1756-07-31
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [62] Processing: Wiener Zeitung 1756-08-04
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [63] Processing: Wiener Zeitung 1756-08-07
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [64] Processing: Wiener Zeitung 1756-08-11
#     - Found 12 pages.
#       Downloading 00000012.jpg...
# [65] Processing: Wiener Zeitung 1756-08-14
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [66] Processing: Wiener Zeitung 1756-08-18
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [67] Processing: Wiener Zeitung 1756-08-21
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [68] Processing: Wiener Zeitung 1756-08-25
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [69] Processing: Wiener Zeitung 1756-08-28
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [70] Processing: Wiener Zeitung 1756-09-01
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [71] Processing: Wiener Zeitung 1756-09-04
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [72] Processing: Wiener Zeitung 1756-09-08
#     - Found 12 pages.
#       Downloading 00000012.jpg...
# [73] Processing: Wiener Zeitung 1756-09-11
#     - Found 12 pages.
#       Downloading 00000012.jpg...
# [74] Processing: Wiener Zeitung 1756-09-15
#     - Found 14 pages.
#       Downloading 00000014.jpg...
# [75] Processing: Wiener Zeitung 1756-09-18
#     - Found 18 pages.
#       Downloading 00000018.jpg...
# [76] Processing: Wiener Zeitung 1756-09-21
#     - Found 14 pages.
#       Downloading 00000014.jpg...
# [77] Processing: Wiener Zeitung 1756-09-25
#     - Found 24 pages.
#       Downloading 00000024.jpg...
# [78] Processing: Wiener Zeitung 1756-09-29
#     - Found 12 pages.
#       Downloading 00000012.jpg...
# [79] Processing: Wiener Zeitung 1756-10-02
#     - Found 16 pages.
#       Downloading 00000016.jpg...
# [80] Processing: Wiener Zeitung 1756-10-06
#     - Found 20 pages.
#       Downloading 00000020.jpg...
# [81] Processing: Wiener Zeitung 1756-10-09
#     - Found 16 pages.
#       Downloading 00000016.jpg...
# [82] Processing: Wiener Zeitung 1756-10-13
#     - Found 20 pages.
#       Downloading 00000020.jpg...
# [83] Processing: Wiener Zeitung 1756-10-16
#     - Found 20 pages.
#       Downloading 00000020.jpg...
# [84] Processing: Wiener Zeitung 1756-10-20
#     - Found 14 pages.
#       Downloading 00000014.jpg...
# [85] Processing: Wiener Zeitung 1756-10-23
#     - Found 24 pages.
#       Downloading 00000024.jpg...
# [86] Processing: Wiener Zeitung 1756-10-27
#     - Found 18 pages.
#       Downloading 00000018.jpg...
# [87] Processing: Wiener Zeitung 1756-10-30
#     - Found 22 pages.
#       Downloading 00000022.jpg...
# [88] Processing: Wiener Zeitung 1756-11-03
#     - Found 24 pages.
#       Downloading 00000024.jpg...
# [89] Processing: Wiener Zeitung 1756-11-06
#     - Found 20 pages.
#       Downloading 00000020.jpg...
# [90] Processing: Wiener Zeitung 1756-11-10
#     - Found 22 pages.
#       Downloading 00000022.jpg...
# [91] Processing: Wiener Zeitung 1756-11-13
#     - Found 24 pages.
#       Downloading 00000024.jpg...
# [92] Processing: Wiener Zeitung 1756-11-17
#     - Found 18 pages.
#       Downloading 00000018.jpg...
# [93] Processing: Wiener Zeitung 1756-11-20
#     - Found 14 pages.
#       Downloading 00000014.jpg...
# [94] Processing: Wiener Zeitung 1756-11-24
#     - Found 12 pages.
#       Downloading 00000012.jpg...
# [95] Processing: Wiener Zeitung 1756-11-27
#     - Found 12 pages.
#       Downloading 00000012.jpg...
# [96] Processing: Wiener Zeitung 1756-12-01
#     - Found 14 pages.
#       Downloading 00000014.jpg...
# [97] Processing: Wiener Zeitung 1756-12-04
#     - Found 20 pages.
#       Downloading 00000020.jpg...
# [98] Processing: Wiener Zeitung 1756-12-08
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [99] Processing: Wiener Zeitung 1756-12-11
#     - Found 16 pages.
#       Downloading 00000016.jpg...
# [100] Processing: Wiener Zeitung 1756-12-15
#     - Found 12 pages.
#       Downloading 00000012.jpg...
# [101] Processing: Wiener Zeitung 1756-12-18
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [102] Processing: Wiener Zeitung 1756-12-22
#     - Found 10 pages.
#       Downloading 00000010.jpg...
# [103] Processing: Wiener Zeitung 1756-12-25
#     - Found 20 pages.
#       Downloading 00000020.jpg...
# [104] Processing: Wiener Zeitung 1756-12-29
#     - Found 10 pages.
#       Downloading 00000010.jpg...
#
# All downloads complete!

# %%
#now export all downloaded folders back to Galaxy for reuse
